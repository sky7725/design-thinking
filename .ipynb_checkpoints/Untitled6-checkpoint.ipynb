# %%
# Use words.txt as the file name
fname = input("words.txt")

# %%
print(fn)

# %%
for i in fn :
    i = i.rstrip()
    print(i.upper())

# %%
count = {'key':123,'go':24}
a = count.items()
print(a)
type(a)
# Out:
# dict_items([('key', 123), ('go', 24)])
# dict_items

# %%
c = {'a':1,'b':22,'c':5}
a=c.items()
print(a)
# Out:
# dict_items([('a', 1), ('b', 22), ('c', 5)])

# %%
tmp=list()
for k,v in c.items():
    tmp.append((v,k))
    
print(tmp)
type(tmp)
# Out:
# [(1, 'a'), (22, 'b'), (5, 'c')]
# list

# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.google.com.tw/')
r.status_code
type(r.text)
# Out:
# str

# %%
# 查詢參數
my_params = {'key1': 'value1', 'key2': 'value2'}

# 將查詢參數加入 GET 請求中
r = requests.get('http://httpbin.org/get', params = my_params)
print(r.url)
# Out:
# http://httpbin.org/get?key1=value1&key2=value2

# %%
import requests
from bs4 import BeautifulSoup
#博客來即時榜單
url='https://www.books.com.tw/web/sys_hourstop/books?loc=act_menu_th_43_001'
#使用get方式向網頁發送請求
html=requests.get(url)
#使用utf-8方式編碼讀取網頁
html.encoding='utf-8'
#使用BeautifulSoup解析原始碼
sp=BeautifulSoup(html.text,'lxml')
m=sp.select('.mod_no')[0].select('.item')
for i in m:
    #讀取榜單排名
    print("%s"%i.find_all('strong')[0].text,end=' ')
    #讀取書名
    print(i.find_all('h4')[0].text)
    #讀取圖片網址
    print(i.select('img')[0]['src'])
# Out:
# 1 全新制50次多益滿分的怪物講師TOEIC多益閱讀攻略+模擬試題+解析(2書+防水書套)
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/077/45/0010774591.jpg&v=5c6e8bbe&w=150&h=150
# 2 為什麼你的退休金只有別人的一半？
# //im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/083/59/0010835976.jpg&v=5d987ebb&w=150&h=150
# 3 全新制怪物講師教學團隊的TOEIC多益5回全真模擬試題+解析(附1MP3+防水書套)
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/076/32/0010763289.jpg&v=5c6e8bbe&w=150&h=150
# 4 全新制50次多益滿分的怪物講師TOEIC多益聽力攻略+模擬試題+解析(2書+1CD+防水書套)
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/077/45/0010774599.jpg&v=5cadd3be&w=150&h=150
# 5 TOEIC L&R TEST多益閱讀解密（2018新制）
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/077/84/0010778409.jpg&v=5ae99370&w=150&h=150
# 6 TOEIC L&R TEST多益文法解密（2018新制）
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/079/28/0010792891.jpg&v=5b43395d&w=150&h=150
# 7 TOEIC L&R TEST多益聽力解密﹝2018全新制﹞（MP3免費下載）
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/077/84/0010778411.jpg&v=5ae99370&w=150&h=150
# 8 故事臺灣史：10個翻轉臺灣的關鍵時刻
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/083/59/0010835985.jpg&v=5d8c851e&w=150&h=150
# 9 媽媽禪：快樂母親覺醒九要
# //im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/083/44/0010834490.jpg&v=5d7a104a&w=150&h=150
# 10 全新制怪物講師教學團隊的TOEIC多益聽力1,200題全真模擬試題＋解析【美國＋台灣多益官方講師聯手推薦】（2書＋32小時多國口音MP3＋防水書套）
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/081/77/0010817719.jpg&v=5ca347bd&w=150&h=150
# 11 故事臺灣史：22個改變臺灣的關鍵人物
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/083
# //im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/071/90/0010719080.jpg&v=5784e374&w=150&h=150
# 99 與焦慮和解：克服過度完美主義、拖延症、害怕批評，從自我檢測中找回生活平衡的實用指南
# //im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/081/34/0010813428.jpg&v=5c63f1d2&w=150&h=150
# 100 投資最重要的事：一本股神巴菲特讀了兩遍的書
# //im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/074/49/0010744933.jpg&v=58a6d0d2&w=150&h=150

# %%
import requests as rq
from bs4 import BeautifulSoup

url = "https://www.ptt.cc/bbs/NBA/index.html" # PTT NBA 板
response = rq.get(url) # 用 requests 的 get 方法把網頁抓下來
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器
print(soup.prettify()) # 把排版後的 html 印出來
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 NBA 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/NBA/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      NBA
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="main-container">
#    <div id="action-bar-container">
#     <div class="action-bar">
#      <div class="btn-group btn-group-dir">
#       <a class="btn selected" href="/bbs/NBA/index.html">
#        看板
#       </a>
#       <a class="btn" href="/man/NBA/index.html">
#        精華區
#       </a>
#      </div>
#      <div class="btn-group btn-group-paging">
#       <a class="btn wide" href="/bbs/NBA/index1.html">
#        最舊
#       </a>
#       <a class="btn wide" href="/bbs/NBA/index6506.html">
#        ‹ 上頁
#       </a>
#       <a class="btn wide disabled">
#        下頁 ›
#       </a>
#       <a class="btn wide" href="/bbs/NBA/index.html">
#        最新
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="r-list-container action-bar-margin bbs-screen">
#     <div class="search-bar">
#      <form action="search" id="search-bar" type="get">
#       <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
#      </form>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        27
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570498213.A.E4D.html">
#        [BOX ] Magic 115:91 Pistons (Preseason)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        guardyo
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Magic+115%3A91+Pistons+%28Preseason%29">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Aguardyo">
#           搜尋看板內 guardyo 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        52
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570498892.A.75C.html">
#        [討論] 姚明跟易建聯孫悅以後怎麼介紹?
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        jay251935
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E5%A7%9A%E6%98%8E%E8%B7%9F%E6%98%93%E5%BB%BA%E8%81%AF%E5%AD%AB%E6%82%85%E4%BB%A5%E5%BE%8C%E6%80%8E%E9%BA%BC%E4%BB%8B%E7%B4%B9%3F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Ajay251935">
#           搜尋看板內 jay251935 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        12
#       </span>
#      </div>
#      <div class="title">
#       (已被Vedan刪除) &lt;kobe142435&gt;1-1(150)
#      </div>
#      <div class="meta">
#       <div class="author">
#        -
#       </div>
#       <div class="article-menu">
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        11
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570499831.A.9BA.html">
#        [BOX ] Knicks 104:99 Wizards (Preseason)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        guardyo
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Knicks+104%3A99+Wizards+%28Preseason%29">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Aguardyo">
#           搜尋看板內 guardyo 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        29
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570499846.A.417.html">
#        Re: [討論] NBA主席Silver的回應大家怎麼看?
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        ctw01
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+NBA%E4%B8%BB%E5%B8%ADSilver%E7%9A%84%E5%9B%9E%E6%87%89%E5%A4%A7%E5%AE%B6%E6%80%8E%E9%BA%BC%E7%9C%8B%3F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Actw01">
#           搜尋看板內 ctw01 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        85
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570500448.A.6E4.html">
#        [外絮] 美國參議員要求Silver取消在中國的熱身賽
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        kairiyu
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E5%A4%96%E7%B5%AE%5D+%E7%BE%8E%E5%9C%8B%E5%8F%83%E8%AD%B0%E5%93%A1%E8%A6%81%E6%B1%82Silver%E5%8F%96%E6%B6%88%E5%9C%A8%E4%B8%AD%E5%9C%8B%E7%9A%84%E7%86%B1%E8%BA%AB%E8%B3%BD">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Akairiyu">
#           搜尋看板內 kairiyu 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        69
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570500748.A.7B6.html">
#        [BOX ] Pelicans 133:109 Hawks (Preseason)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        guardyo
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Pelicans+133%3A109+Hawks+%28Preseason%29">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Aguardyo">
#           搜尋看板內 guardyo 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        17
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570501592.A.5D1.html">
#        [BOX ] Bucks 122:112 Bulls (Preseason)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        guardyo
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5BBOX+%5D+Bucks+122%3A112+Bulls+%28Preseason%29">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Aguardyo">
#           搜尋看板內 guardyo 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f0">
#        X3
#       </span>
#      </div>
#      <div class="title">
#       (已被namie810303刪除) &lt;ilovedt&gt;1-1 1-2
#      </div>
#      <div class="meta">
#       <div class="author">
#        -
#       </div>
#       <div class="article-menu">
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E5%A4%96%E7%B5%AE%5D+%E7%BE%8E%E5%9C%8B%E5%8F%83%E8%AD%B0%E5%93%A1%E8%A6%81%E6%B1%82Silver%E5%8F%96%E6%B6%88%E5%9C%A8%E4%B8%AD%E5%9C%8B%E7%9A%84%E7%86%B1%E8%BA%AB%E8%B3%BD">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Alariat">
#           搜尋看板內 lariat 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-list-sep">
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1558698194.A.1DC.html">
#        [公告] 板規v6.5
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Vedan
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8Fv6.5">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3AVedan">
#           搜尋看板內 Vedan 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        5/24
#       </div>
#       <div class="mark">
#        !
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f1">
#        爆
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1561360084.A.52D.html">
#        [公告] 樂透取消及未來不再開啟樂透
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Vedan
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%A8%82%E9%80%8F%E5%8F%96%E6%B6%88%E5%8F%8A%E6%9C%AA%E4%BE%86%E4%B8%8D%E5%86%8D%E9%96%8B%E5%95%9F%E6%A8%82%E9%80%8F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3AVedan">
#           搜尋看板內 Vedan 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        6/24
#       </div>
#       <div class="mark">
#        M
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        13
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1569739966.A.26D.html">
#        [情報] PRESEASON Schedule 賽程 October 19–20
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        JerroLi
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+PRESEASON+Schedule+%E8%B3%BD%E7%A8%8B+October+19%E2%80%9320">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3AJerroLi">
#           搜尋看板內 JerroLi 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        9/29
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        5
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570035569.A.D08.html">
#        [公告] 2019板主選舉投票開始
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Vedan
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+2019%E6%9D%BF%E4%B8%BB%E9%81%B8%E8%88%89%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3AVedan">
#           搜尋看板內 Vedan 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/03
#       </div>
#       <div class="mark">
#        M
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        37
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1570465861.A.7B7.html">
#        [活動] 壹零柒事變一周年紀念活動
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        ericf129
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/NBA/search?q=thread%3A%5B%E6%B4%BB%E5%8B%95%5D+%E5%A3%B9%E9%9B%B6%E6%9F%92%E4%BA%8B%E8%AE%8A%E4%B8%80%E5%91%A8%E5%B9%B4%E7%B4%80%E5%BF%B5%E6%B4%BB%E5%8B%95">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/NBA/search?q=author%3Aericf129">
#           搜尋看板內 ericf129 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        10/08
#       </div>
#       <div class="mark">
#        M
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#  </body>
# </html>
#
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>

# %%
import requests as rq
from bs4 import BeautifulSoup

url = "https://www.ptt.cc/bbs/NBA/index.html" # PTT NBA 板
response = rq.get(url) # 用 requests 的 get 方法把網頁抓下來
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器
print(soup.title) # 把排版後的 html 印出來
print(soup.title.name)
print(soup.title.string)
print(soup.title.parent.name) 
print(soup.a)
print(soup.find_all('href'))
# Out:
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# title
# 看板 NBA 文章列表 - 批踢踢實業坊
# head
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# []

# %%
from requests import get
url="http://httpbin.org/get"
#1.資料以字典的形式
data={"project":"Python"}
#2.向伺服器傳送get請求
response=get(url,params=data)
#3.使用response處理伺服器的響應內容
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
from requests import get
url="http://httpbin.org/get"
#1.資料以字典的形式
data={"project":"Python"}
#2.新增請求頭資訊
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) "
"AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36"}
#3.向伺服器傳送get請求
response=get(url,params=data,headers=headers)
#4.使用response處理伺服器的響應內容
print(response.text)
# Out:
# {
#   "args": {
#     "project": "Python"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36"
#   },
#   "origin": "140.119.120.6, 140.119.120.6",
#   "url": "https://httpbin.org/get?project=Python"
# }
