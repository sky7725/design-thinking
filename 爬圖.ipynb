# %%
import requests

import urllib.request

from bs4 import BeautifulSoup

import os

import time





url = 'https://www.google.com/search?q=%E7%BE%8E%E5%A5%B3&rlz=1C2CAFB_enTW617TW617&source=lnms&tbm=isch&sa=X&ved=0ahUKEwictOnTmYDcAhXGV7wKHX-OApwQ_AUICigB&biw=1128&bih=960'

photolimit = 10



headers = {'User-Agent': 'Mozilla/5.0'}

response = requests.get(url,headers = headers) #使用header避免訪問受到限制

soup = BeautifulSoup(response.content, 'html.parser')

items = soup.find_all('img')

folder_path ='./photo/'

if (os.path.exists(folder_path) == False): #判斷資料夾是否存在

    os.makedirs(folder_path) #Create folder



for index , item in enumerate (items):

    if (item and index < photolimit ):

        html = requests.get(item.get('src')) # use 'get' to get photo link path , requests = send request

        img_name = folder_path + str(index + 1) + '.png'



        with open(img_name,'wb') as file: #以byte的形式將圖片數據寫入

            file.write(html.content)

            file.flush()

        file.close() #close file

        print('第 %d 張' % (index + 1))

        time.sleep(1)



print('Done')
# Out:
# 第 1 張
# 第 2 張
# 第 3 張
# 第 4 張
# 第 5 張
# 第 6 張
# 第 7 張
# 第 8 張
# 第 9 張
# 第 10 張
# Done

# %%
items = soup.find_all('img')
items[1]
# Out:
# <img alt="「美女」的圖片搜尋結果" height="148" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSTIjgGtnKYY0B4_lHxORxeZ5bO4uNiiy4fanZVFexaIpUUJZdOkzgP6wc" width="100"/>

# %%
import requests
from bs4 import BeautifulSoup
import json
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'}
bank = requests.get('https://24h.pchome.com.tw/store/DSAA4G',headers=headers)
soup = BeautifulSoup(bank.text,'lxml')
soup.select('font')
# Out:
# []

# %%
for i in range(50):
    url = 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=ssd&page=' + str(i+1) + '&sort=sale/dc' 
    print(url)
    k = requests.get(url=url,headers=headers)
    jd = json.loads(k.text)
    type(jd['prods'][0]['name'])
    print(len(jd['prods']))
    for con in jd['prods']:
        print(con['name'],con['price'])
# Out:
# https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=ssd&page=1&sort=sale/dc
# 20
# WD SSD 1TB 2.5吋 3D NAND固態硬碟(藍標) 3980
# WD SSD 500GB 2.5吋 3D NAND固態硬碟(藍標) 2190
# SanDisk SSD Plus 240GB 2.5吋SATAIII固態硬碟(G26) 988
# WD My Passport SSD 1TB 外接式固態硬碟 USB3.1 Gen2 5990
# WD SSD 250GB 2.5吋 3D NAND 固態硬碟(藍標) 1490
# SanDisk SSD Plus 480GB 2.5吋SATAIII固態硬碟(G26) 1688
# WD 黑標 SN750 1TB NVMe PCIe SSD固態硬碟 6690
# SanDisk Extreme Pro 1TB M.2 NVMe 3D SSD 5688
# WD 黑標 SN750 500GB NVMe PCIe SSD固態硬碟(WDS500G3X0C) 3450
# Seagate Fast SSD 500GB 外接式固態硬碟 3390
# WD SSD 480GB 2.5吋固態硬碟(綠標) 1750
# Seagate Fast SSD 2TB 外接式固態硬碟 12790
# WD SSD 2TB 2.5吋 3D NAND固態硬碟(藍標) 9450
# SanDisk SSD Plus 1TB 2.5吋SATAIII固態硬碟(G26) 3388
# 技嘉AORUS NVMe Gen4 1TB SSD(GP-ASM2NE6100TTTD) 9090
# WD SSD 4TB 2.5吋 3D NAND固態硬碟(藍標) 16790
# WD 藍標 SN500 500GB NVMe PCIe SSD固態硬碟(WDS500G1B0C) 2290
# WD SSD 480GB M.2 2280 SATA 固態硬碟(綠標) 1750
# Seagate Fast SSD 1TB 外接式固態硬碟 5890
# WD 黑標 SN750 1TB NVMe PCIe SSD固態硬碟(WDS100T3X0C) 6690
# ...

# %%
soup =BeautifulSoup(bank.text)
for items in soup.select('table'):
    print(items.text)[0]
# Out:
# 幣別
# 幣別
# 現金匯率
#
# 即期匯率
#
#
# 遠期匯率
#
# 歷史匯率
# 歷史匯率
# 現金匯率
#
# 即期匯率
#
#
#
#
#
#
# 本行買入
#
#
#
#
# 本行賣出
#
#
#
#
# 本行買入
#
#
#
#
# 本行賣出
#
#
#
# 本行買入
# 本行賣出
# 本行買入
# 本行賣出
#
#
#
#
#
#
#
#
#
#
#
#                                 美金 (USD)
#
#
#                                 美金 (USD)
#
#
#
# 30.435
# 31.105
# 30.785
# 30.885
# 查詢
# 查詢
# 30.435
# 31.105
# 30.785
# 30.885
#
#
#
#
#
#
#
#
#
#                                 港幣 (HKD)
#
#
#                                 港幣 (HKD)
#
#
#
# 3.775
# 3.979
# 3.901
# 3.961
# 查詢
# 查詢
# 3.775
# 3.979
# 3.901
# 3.961
#
#
#
#
#
#
#
#
#
#                                 英鎊 (GBP)
#
#
#                                 英鎊 (GBP)
#
#
#
# 36.5
# 38.62
# 37.5
# 37.92
# 查詢
# 查詢
# 36.5
# 38.62
# 37.5
# 37.92
#
#
#
#
#
#
#
#
#
#                                 澳幣 (AUD)
#
#
#                                 澳幣 (AUD)
#
#
#
# 20.4
# 21.18
# 20.67
# 20.9
# 查詢
# 查詢
# 20.4
# 21.18
# 20.67
# 20.9
#
#
#
#
#
#
#
#
#
#                                 加拿大幣 (CAD)
#
#
# ...
